# %%
from __future__ import print_function
from __future__ import division
from __future__ import unicode_literals
from __future__ import absolute_import

import numpy as np
import pandas as pd
pd.set_option("display.max_columns",40)

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Load the data

# %%
from higgsml import load_higgs

# %%
data = load_higgs()
data.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# ...

# %% [markdown]
# # Preprocessing

# %%
from preprocessing import clean_columns
from preprocessing import handle_missing_values

# %%
data = clean_columns(data)

# %%
data.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               3.064      41.928     197.760                 1.582
# ...

# %%
data = handle_missing_values(data)

# %%
data.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2         0.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1                  0.00             0.000                0.000
# 2                  0.00             0.000                0.000
# 3                  0.00             0.000                0.000
# 4                  0.00             0.000                0.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  DER_pt_ratio_lep_tau  \
# 0               3.064      41.928     197.760                 1.582
# ...

# %% [markdown]
# # Tau Energy Scale

# %%
from preprocessing import skew
affected_columns = ['PRI_tau_pt', 'PRI_met', 'DER_mass_vis', 
                    'DER_mass_transverse_met_lep', 'DER_met_phi_centrality', 'DER_sum_pt',
                   'DER_pt_ratio_lep_tau']

# %%
data_skew_p30 = skew(data, sysTauEnergyScale=1.3)  # (1 + 0.3) ie +30%

# %%
data_skew_m30 = skew(data, sysTauEnergyScale=0.7)  # (1 - 0.3) ie -30%

# %%
data.hist(affected_columns, figsize=(15, 15))
plt.show()

# %%
data_skew_p30.hist(affected_columns, figsize=(15, 15))
plt.show()

# %%
data_skew_m30.hist(affected_columns, figsize=(15, 15))
plt.show()
